# %%
from pandas import *

# %%
df = read_csv('/Users/yeqing/projects/taixiangny/merchants/merchants/data/taobao.2016101218.csv')

df_y = df[df['query'] == '羊肚菌']
# df_y[df_y['raw_title'].str.contains('凤凰')].T
df_y[df_y['id'] == 42901118677].T
# Out:
#                                                                        2
# sc_delivery_rating                                                   484
# weight                                                                40
# sc_service_rating                                                    487
# rank                                                                   3
# shop_id                                                       2133478936
# id                                                           42901118677
# query                                                                羊肚菌
# sc_service_pct                                                      2734
# pic_url                //g-search3.alicdn.com/img/bao/uploaded/i4/i3/...
# category                                                     5.00098e+07
# view_price                                                           138
# shop_url               //store.taobao.com/shop/view_shop.htm?user_num...
# ...
